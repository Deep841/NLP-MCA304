# %% [markdown]
# Tensor, Tensorflow vs Pytorch, np-array vs tensor, int a,b,c RAM m store hogi, CPU memory m store hoti hai cheeze and one by one hoti h cheeze execute, tensor m auto gradient , tensor m apne aap hi partial derivatives phle hi bna kr rakh leta h, GPU ko Tensor chahiye sare varibales ko tensor m convert krna hoga, sab kuch tensor m convert krna hoga, fucntion to convert to tensor ,train - test ko tensor m convert , list ko tenosr m convert krna , keras, relu fuction, given eg m 16 hiden layer, x.shape[0] mtlb rows vs x.shape[1] mtlb cols, x1 to x30 cols , hyperparamter tunning hidden layer ke nodes ka number change krna , 16 - in hidden layer 1 then 8 then 1 aur last vale pe sigmoid fucntion lg rha h, binary cross entropy = ylodp + (1-y)log1-p , adam GD , spare cateogrical entropy , ab model ko train, .predict vs .evaluate , functional API , multi model data set
